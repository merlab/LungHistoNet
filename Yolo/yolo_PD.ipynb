# %%
from ultralytics import YOLO

model = YOLO("yolo11l.pt")

'''
yolov8n.pt 
yolov8s.pt
yolov8m.pt
yolov8l.pt
yolov8x.pt
yolov10x.pt
yolo11x.pt
'''
model.to('cuda')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11l.pt to 'yolo11l.pt'...
# 100%|██████████| 49.0M/49.0M [00:00<00:00, 65.1MB/s]
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x C3k(
#             (cv1): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x C3k(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x C3k(
#             (cv1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x C3k(
#             (cv1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): C2PSA(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): Sequential(
#           (0): PSABlock(
#             (attn): Attention(
#               (qkv): Conv(
#                 (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (proj): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (pe): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (ffn): Sequential(
#               (0): Conv(
#                 (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#           )
#           (1): PSABlock(
#             (attn): Attention(
#               (qkv): Conv(
#                 (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (proj): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#               (pe): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#             (ffn): Sequential(
#               (0): Conv(
#                 (conv): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): Identity()
#               )
#             )
#           )
#         )
#       )
#       (11): Upsample(scale_factor=2.0, mode='nearest')
#       (12): Concat()
#       (13): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x C3k(
#             (cv1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (14): Upsample(scale_factor=2.0, mode='nearest')
#       (15): Concat()
#       (16): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x C3k(
#             (cv1): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (17): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (18): Concat()
#       (19): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x C3k(
#             (cv1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (20): Conv(
#         (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (21): Concat()
#       (22): C3k2(
#         (cv1): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x C3k(
#             (cv1): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv3): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (m): Sequential(
#               (0): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#               (1): Bottleneck(
#                 (cv1): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#                 (cv2): Conv(
#                   (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#                   (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                   (act): SiLU(inplace=True)
#                 )
#               )
#             )
#           )
#         )
#       )
#       (23): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1-2): 2 x Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(256, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1-2): 2 x Sequential(
#             (0): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=512, bias=False)
#                 (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (1): Sequential(
#               (0): DWConv(
#                 (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=256, bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#               (1): Conv(
#                 (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#                 (act): SiLU(inplace=True)
#               )
#             )
#             (2): Conv2d(256, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %%
from ultralytics.data.utils import check_det_dataset
dataset_info = check_det_dataset("ProteinaceousDebris.yaml")

print(dataset_info)
# Out:
# {'path': PosixPath('/home/amir_ebrahimi/Documents/LungHistoNet/Yolo/Data/YOLO_PD/dataset'), 'train': '/home/amir_ebrahimi/Documents/LungHistoNet/Yolo/Data/YOLO_PD/dataset/images/train', 'val': '/home/amir_ebrahimi/Documents/LungHistoNet/Yolo/Data/YOLO_PD/dataset/images/val', 'names': {0: 'Proteinaceous Debris'}, 'save_period': -1, 'cache': False, 'device': 'cuda:0', 'workers': 8, 'project': None, 'exist_ok': False, 'pretrained': True, 'optimizer': 'auto', 'verbose': True, 'seed': 0, 'deterministic': True, 'single_cls': True, 'rect': False, 'cos_lr': True, 'close_mosaic': 20, 'resume': False, 'amp': True, 'fraction': 1.0, 'profile': False, 'freeze': None, 'multi_scale': False, 'overlap_mask': True, 'mask_ratio': 4, 'dropout': 0.0, 'split': 'val', 'save_json': False, 'save_hybrid': False, 'conf': None, 'iou': 0.6, 'max_det': 300, 'half': False, 'dnn': False, 'plots': True, 'source': None, 'vid_stride': 1, 'stream_buffer': False, 'visualize': False, 'augment': False, 'agnostic_nms': False, 'classes': None, 'retina_masks': False, 'embed': None, 'show': False, 'save_frames': False, 'save_txt': False, 'save_conf': False, 'save_crop': False, 'show_labels': True, 'show_conf': True, 'show_boxes': True, 'line_width': None, 'format': 'torchscript', 'keras': False, 'optimize': False, 'int8': False, 'dynamic': False, 'simplify': True, 'opset': None, 'workspace': None, 'nms': False, 'lr0': 0.01, 'lrf': 0.01, 'momentum': 0.937, 'weight_decay': 0.0005, 'warmup_epochs': 3.0, 'warmup_momentum': 0.8, 'warmup_bias_lr': 0.1, 'box': 7.5, 'cls': 0.5, 'dfl': 1.5, 'pose': 12.0, 'kobj': 1.0, 'nbs': 64, 'hsv_h': 0.015, 'hsv_s': 0.7, 'hsv_v': 0.4, 'degrees': 0.0, 'translate': 0.1, 'scale': 0.5, 'shear': 0.0, 'perspective': 0.0, 'flipud': 0.0, 'fliplr': 0.5, 'bgr': 0.0, 'mosaic': 1.0, 'mixup': 0.0, 'copy_paste': 0.0, 'copy_paste_mode': 'flip', 'auto_augment': 'randaugment', 'erasing': 0.4, 'crop_fraction': 1.0, 'cfg': None, 'tracker': 'botsort.yaml', 'yaml_file': 'ProteinaceousDebris.yaml', 'nc': 1}

# %%
results = model.train(
    data="ProteinaceousDebris.yaml",
    epochs=100,  
    imgsz=1024,
    batch=8,
    patience=10, 
    name="yolov11l_1024_dataPD_ep100_aug_b16" 
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.196 available 😃 Update with 'pip install -U ultralytics'
# engine/trainer: task=detect, mode=train, model=yolo11l.pt, data=ProteinaceousDebris.yaml, epochs=100, time=None, patience=10, batch=8, imgsz=1024, save=True, save_period=-1, cache=False, device=cuda:0, workers=8, project=None, name=yolov11l_1024_dataPD_ep100_aug_b16, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/yolov11l_1024_dataPD_ep100_aug_b16
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  2    173824  ultralytics.nn.modules.block.C3k2            [128, 256, 2, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  2    691712  ultralytics.nn.modules.block.C3k2            [256, 512, 2, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  2   2234368  ultralytics.nn.modules.block.C3k2            [512, 512, 2, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  2   1455616  ultralytics.nn.modules.block.C2PSA           [512, 512, 2]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    756736  ultralytics.nn.modules.block.C3k2            [1024, 256, 2, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2   2365440  ultralytics.nn.modules.block.C3k2            [768, 512, 2, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   2496512  ultralytics.nn.modules.block.C3k2            [1024, 512, 2, True]
#  23        [16, 19, 22]  1   1411795  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# YOLO11l summary: 357 layers, 25,311,251 parameters, 25,311,235 gradients, 87.3 GFLOPs
#
# Transferred 1009/1015 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/yolov11l_1024_dataPD_ep100_aug_b16', view at http://localhost:6006/
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/Data/YOLO_PD/dataset/labels/train.cache... 100 images, 0 backgrounds, 0 corrupt: 100%|██████████| 100/100 [00:00<?, ?it/s]
# val: Scanning /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/Data/YOLO_PD/dataset/labels/val.cache... 25 images, 0 backgrounds, 0 corrupt: 100%|██████████| 25/25 [00:00<?, ?it/s]
# Plotting labels to runs/detect/yolov11l_1024_dataPD_ep100_aug_b16/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 167 weight(decay=0.0), 174 weight(decay=0.0005), 173 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 1024 train, 1024 val
# Using 8 dataloader workers
# Logging results to runs/detect/yolov11l_1024_dataPD_ep100_aug_b16
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      13.4G      3.455      4.473      2.853         51       1024: 100%|██████████| 13/13 [00:05<00:00,  2.27it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.17it/s]
#                    all         25        166     0.0117     0.0181    0.00315   0.000788
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      13.2G      3.017        3.7      2.366         35       1024: 100%|██████████| 13/13 [00:05<00:00,  2.31it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  2.99it/s]
#                    all         25        166     0.0111      0.217    0.00704    0.00209
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      13.3G      2.878      3.573      2.318         37       1024: 100%|██████████| 13/13 [00:05<00:00,  2.32it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.05it/s]
#                    all         25        166      0.004      0.181    0.00244   0.000764
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      13.2G      2.983      3.539      2.413         47       1024: 100%|██████████| 13/13 [00:05<00:00,  2.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.61it/s]
#                    all         25        166    0.00196     0.0723    0.00103   0.000292
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      13.3G      2.934      3.495      2.412         27       1024: 100%|██████████| 13/13 [00:05<00:00,  2.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.21it/s]
#                    all         25        166          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      13.2G      2.969      3.846      2.369         31       1024: 100%|██████████| 13/13 [00:05<00:00,  2.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.54it/s]
#                    all         25        166    0.00213     0.0964    0.00119    0.00028
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      13.3G      2.976      3.518      2.433         26       1024: 100%|██████████| 13/13 [00:05<00:00,  2.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.12it/s]
#                    all         25        166          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      13.3G      2.965      3.525      2.393         58       1024: 100%|██████████| 13/13 [00:05<00:00,  2.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.24it/s]
#                    all         25        166          0          0          0          0
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      13.3G      3.017      3.485       2.38         24       1024: 100%|██████████| 13/13 [00:05<00:00,  2.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.11it/s]
#                    all         25        166   0.000667     0.0301   0.000385   0.000108
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      13.3G       2.87      3.528      2.293         53       1024: 100%|██████████| 13/13 [00:05<00:00,  2.35it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.11it/s]
#                    all         25        166   0.000267      0.012   0.000186   4.22e-05
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      13.3G      2.824        3.5      2.308         35       1024: 100%|██████████| 13/13 [00:05<00:00,  2.33it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.09it/s]
#                    all         25        166     0.0016     0.0723   0.000875   0.000235
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      13.3G      2.843      3.342      2.285         31       1024: 100%|██████████| 13/13 [00:05<00:00,  2.34it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.77it/s]
#                    all         25        166    0.00254     0.0241   0.000613   0.000166
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 2, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 12 epochs completed in 0.025 hours.
# Optimizer stripped from runs/detect/yolov11l_1024_dataPD_ep100_aug_b16/weights/last.pt, 51.3MB
# Optimizer stripped from runs/detect/yolov11l_1024_dataPD_ep100_aug_b16/weights/best.pt, 51.3MB
#
# Validating runs/detect/yolov11l_1024_dataPD_ep100_aug_b16/weights/best.pt...
# Ultralytics 8.3.80 🚀 Python-3.12.9 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX 4000 Ada Generation, 19925MiB)
# YOLO11l summary (fused): 190 layers, 25,280,083 parameters, 0 gradients, 86.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.11it/s]
#                    all         25        166     0.0105      0.217    0.00703    0.00211
# Speed: 0.2ms preprocess, 16.2ms inference, 0.0ms loss, 7.9ms postprocess per image
# Results saved to runs/detect/yolov11l_1024_dataPD_ep100_aug_b16

# %%
from ultralytics import YOLO
model_old = YOLO("runs/detect/yolov11l_1024_dataPD_ep100_aug_b16/weights/best.pt")
results = model_old.predict(source="test/injured", save=True, show_labels=False, show_conf=False)
# results = model.predict(source="test/injured", save=True, show_labels=False, show_conf=False)
# Out:
# image 1/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_24555_140484.png: 640x1024 1 Proteinaceous Debris, 19.8ms
# image 2/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_24555_142520.png: 640x1024 (no detections), 13.1ms
# image 3/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_24555_144556.png: 640x1024 (no detections), 13.1ms
# image 4/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_26192_80422.png: 640x1024 2 Proteinaceous Debriss, 13.0ms
# image 5/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_26192_81440.png: 640x1024 26 Proteinaceous Debriss, 13.0ms
# image 6/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_27829_82458.png: 640x1024 33 Proteinaceous Debriss, 13.0ms
# image 7/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_29466_49882.png: 640x1024 5 Proteinaceous Debriss, 13.0ms
# image 8/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_29466_53954.png: 640x1024 12 Proteinaceous Debriss, 13.0ms
# image 9/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_29466_55990.png: 640x1024 16 Proteinaceous Debriss, 13.0ms
# image 10/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_29466_58026.png: 640x1024 6 Proteinaceous Debriss, 13.7ms
# image 11/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_29466_79404.png: 640x1024 2 Proteinaceous Debriss, 13.0ms
# image 12/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_29466_84494.png: 640x1024 4 Proteinaceous Debriss, 13.0ms
# image 13/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_29466_85512.png: 640x1024 2 Proteinaceous Debriss, 13.0ms
# image 14/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_29466_86530.png: 640x1024 (no detections), 13.0ms
# image 15/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_139466.png: 640x1024 2 Proteinaceous Debriss, 13.0ms
# image 16/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_140484.png: 640x1024 5 Proteinaceous Debriss, 13.0ms
# image 17/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_142520.png: 640x1024 6 Proteinaceous Debriss, 13.0ms
# image 18/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_145574.png: 640x1024 1 Proteinaceous Debris, 13.0ms
# image 19/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_48864.png: 640x1024 10 Proteinaceous Debriss, 13.0ms
# image 20/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_49882.png: 640x1024 18 Proteinaceous Debriss, 13.0ms
# image 21/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_50900.png: 640x1024 3 Proteinaceous Debriss, 13.0ms
# image 22/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_57008.png: 640x1024 5 Proteinaceous Debriss, 13.0ms
# image 23/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_79404.png: 640x1024 4 Proteinaceous Debriss, 13.0ms
# image 24/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_80422.png: 640x1024 23 Proteinaceous Debriss, 13.0ms
# image 25/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_82458.png: 640x1024 10 Proteinaceous Debriss, 13.0ms
# image 26/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_83476.png: 640x1024 6 Proteinaceous Debriss, 13.0ms
# image 27/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_31103_85512.png: 640x1024 11 Proteinaceous Debriss, 13.0ms
# image 28/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_139466.png: 640x1024 3 Proteinaceous Debriss, 13.0ms
# image 29/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_142520.png: 640x1024 (no detections), 13.0ms
# image 30/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_145574.png: 640x1024 (no detections), 13.0ms
# image 31/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_146592.png: 640x1024 2 Proteinaceous Debriss, 13.0ms
# image 32/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_50900.png: 640x1024 5 Proteinaceous Debriss, 13.0ms
# image 33/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_51918.png: 640x1024 17 Proteinaceous Debriss, 13.1ms
# image 34/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_53954.png: 640x1024 9 Proteinaceous Debriss, 13.0ms
# image 35/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_54972.png: 640x1024 15 Proteinaceous Debriss, 13.0ms
# image 36/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_58026.png: 640x1024 (no detections), 13.0ms
# image 37/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_78386.png: 640x1024 9 Proteinaceous Debriss, 13.0ms
# image 38/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_79404.png: 640x1024 22 Proteinaceous Debriss, 13.0ms
# image 39/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_80422.png: 640x1024 44 Proteinaceous Debriss, 13.0ms
# image 40/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_81440.png: 640x1024 34 Proteinaceous Debriss, 13.0ms
# image 41/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_82458.png: 640x1024 13 Proteinaceous Debriss, 13.0ms
# image 42/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_83476.png: 640x1024 14 Proteinaceous Debriss, 13.0ms
# image 43/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_84494.png: 640x1024 5 Proteinaceous Debriss, 13.0ms
# image 44/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_32740_85512.png: 640x1024 1 Proteinaceous Debris, 13.0ms
# image 45/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_34377_140484.png: 640x1024 1 Proteinaceous Debris, 13.1ms
# image 46/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_34377_82458.png: 640x1024 10 Proteinaceous Debriss, 13.0ms
# image 47/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_34377_85512.png: 640x1024 7 Proteinaceous Debriss, 13.0ms
# image 48/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_36014_139466.png: 640x1024 14 Proteinaceous Debriss, 13.0ms
# image 49/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_36014_142520.png: 640x1024 13 Proteinaceous Debriss, 13.0ms
# image 50/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_36014_147610.png: 640x1024 (no detections), 13.0ms
# image 51/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_36014_76350.png: 640x1024 (no detections), 13.0ms
# image 52/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_36014_77368.png: 640x1024 7 Proteinaceous Debriss, 13.3ms
# image 53/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_36014_83476.png: 640x1024 7 Proteinaceous Debriss, 13.0ms
# image 54/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_36014_84494.png: 640x1024 2 Proteinaceous Debriss, 13.0ms
# image 55/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_36014_85512.png: 640x1024 2 Proteinaceous Debriss, 13.0ms
# image 56/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_37651_140484.png: 640x1024 (no detections), 13.0ms
# image 57/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_37651_143538.png: 640x1024 5 Proteinaceous Debriss, 13.0ms
# image 58/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_37651_145574.png: 640x1024 2 Proteinaceous Debriss, 13.0ms
# image 59/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_37651_170006.png: 640x1024 4 Proteinaceous Debriss, 13.0ms
# image 60/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_37651_174078.png: 640x1024 2 Proteinaceous Debriss, 13.0ms
# image 61/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_37651_82458.png: 640x1024 18 Proteinaceous Debriss, 13.0ms
# image 62/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_37651_83476.png: 640x1024 10 Proteinaceous Debriss, 13.0ms
# image 63/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_39288_140484.png: 640x1024 8 Proteinaceous Debriss, 13.0ms
# image 64/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_39288_143538.png: 640x1024 1 Proteinaceous Debris, 13.0ms
# image 65/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_39288_146592.png: 640x1024 7 Proteinaceous Debriss, 13.0ms
# image 66/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_40925_142520.png: 640x1024 (no detections), 13.0ms
# image 67/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_40925_145574.png: 640x1024 3 Proteinaceous Debriss, 13.0ms
# image 68/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_40925_173060.png: 640x1024 3 Proteinaceous Debriss, 13.0ms
# image 69/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_40925_174078.png: 640x1024 (no detections), 13.0ms
# image 70/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_40925_175096.png: 640x1024 (no detections), 13.0ms
# image 71/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_42562_140484.png: 640x1024 5 Proteinaceous Debriss, 13.1ms
# image 72/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_42562_172042.png: 640x1024 1 Proteinaceous Debris, 13.0ms
# image 73/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_44199_144556.png: 640x1024 4 Proteinaceous Debriss, 13.0ms
# image 74/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_44199_146592.png: 640x1024 (no detections), 13.0ms
# image 75/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_44199_147610.png: 640x1024 (no detections), 13.1ms
# image 76/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_44199_174078.png: 640x1024 (no detections), 13.0ms
# image 77/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_45836_144556.png: 640x1024 20 Proteinaceous Debriss, 13.0ms
# image 78/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_47473_165934.png: 640x1024 8 Proteinaceous Debriss, 13.0ms
# image 79/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_49110_170006.png: 640x1024 16 Proteinaceous Debriss, 13.0ms
# image 80/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_49110_171024.png: 640x1024 15 Proteinaceous Debriss, 13.0ms
# image 81/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_49110_172042.png: 640x1024 1 Proteinaceous Debris, 13.0ms
# image 82/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_49110_173060.png: 640x1024 7 Proteinaceous Debriss, 13.0ms
# image 83/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_50747_170006.png: 640x1024 3 Proteinaceous Debriss, 13.0ms
# image 84/84 /home/amir_ebrahimi/Documents/LungHistoNet/Yolo/test/injured/tile_50747_171024.png: 640x1024 7 Proteinaceous Debriss, 13.0ms
# Speed: 1.8ms preprocess, 13.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 1024)
# Results saved to runs/detect/predict2

# %% [markdown]
# # CV implementation

# %%
import os
from shutil import copyfile
from sklearn.model_selection import KFold
from ultralytics import YOLO

dataset_path = "/home/gandalf/Documents/Code/Lung_Injury/YOLO/dataset"
images_train_path = os.path.join(dataset_path, "images", "train")
labels_train_path = os.path.join(dataset_path, "labels", "train")

image_files = [f for f in os.listdir(images_train_path) if f.endswith(".png")]

k = 5  
kf = KFold(n_splits=k, shuffle=True, random_state=42)

for fold, (train_idx, val_idx) in enumerate(kf.split(image_files)):
    print(f"Training on Fold {fold + 1}/{k}")

    fold_path = os.path.join(dataset_path, f"fold_{fold + 1}")
    os.makedirs(fold_path, exist_ok=True)
    os.makedirs(os.path.join(fold_path, "images", "train"), exist_ok=True)
    os.makedirs(os.path.join(fold_path, "images", "val"), exist_ok=True)
    os.makedirs(os.path.join(fold_path, "labels", "train"), exist_ok=True)
    os.makedirs(os.path.join(fold_path, "labels", "val"), exist_ok=True)

    for idx in train_idx:
        image_name = image_files[idx]
        label_name = image_name.replace(".png", ".txt")
        copyfile(os.path.join(images_train_path, image_name), os.path.join(fold_path, "images", "train", image_name))
        copyfile(os.path.join(labels_train_path, label_name), os.path.join(fold_path, "labels", "train", label_name))

    for idx in val_idx:
        image_name = image_files[idx]
        label_name = image_name.replace(".png", ".txt")
        copyfile(os.path.join(images_train_path, image_name), os.path.join(fold_path, "images", "val", image_name))
        copyfile(os.path.join(labels_train_path, label_name), os.path.join(fold_path, "labels", "val", label_name))

    yaml_content = f"""
    path: {fold_path}
    train: images/train
    val: images/val

    names:
      0: neutrophil
    """
    with open(os.path.join(fold_path, "neutrophils_fold.yaml"), "w") as f:
        f.write(yaml_content)

    model = YOLO("yolov8x.pt")
    model.train(
        data=os.path.join(fold_path, "neutrophils_fold.yaml"),
        epochs=1,
        imgsz=640,
        batch=16,
        workers=-1,
        name=f"yolov8_neutrophils_fold_{fold + 1}"
    )
# Out:
# Training on Fold 1/5
# New https://pypi.org/project/ultralytics/8.3.74 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.73 🚀 Python-3.12.9 torch-2.6.0+cu124 CPU (Intel Core(TM) Ultra 7 165H)
# engine/trainer: task=detect, mode=train, model=yolov8x.pt, data=/home/gandalf/Documents/Code/Lung_Injury/YOLO/dataset/fold_1/neutrophils_fold.yaml, epochs=1, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=-1, project=None, name=yolov8_neutrophils_fold_1, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/yolov8_neutrophils_fold_1
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1   1844480  ultralytics.nn.modules.conv.Conv             [320, 640, 3, 2]
#   6                  -1  6  13117440  ultralytics.nn.modules.block.C2f             [640, 640, 6, True]
#   7                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#   8                  -1  3   6969600  ultralytics.nn.modules.block.C2f             [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  16                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  3   7174400  ultralytics.nn.modules.block.C2f             [960, 640, 3]
#  19                  -1  1   3687680  ultralytics.nn.modules.conv.Conv             [640, 640, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  3   7379200  ultralytics.nn.modules.block.C2f             [1280, 640, 3]
#  22        [15, 18, 21]  1   8718931  ultralytics.nn.modules.head.Detect           [1, [320, 640, 640]]
# Model summary: 365 layers, 68,153,571 parameters, 68,153,555 gradients, 258.1 GFLOPs
#
# Transferred 589/595 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/yolov8_neutrophils_fold_1', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /home/gandalf/Documents/Code/Lung_Injury/YOLO/dataset/fold_1/labels/train.cache... 79 images, 0 backgrounds, 0 corrupt: 100%|██████████| 79/79 [00:00<?, ?it/s]
# val: Scanning /home/gandalf/Documents/Code/Lung_Injury/YOLO/dataset/fold_1/labels/val.cache... 20 images, 0 backgrounds, 0 corrupt: 100%|██████████| 20/20 [00:00<?, ?it/s]
# Plotting labels to runs/detect/yolov8_neutrophils_fold_1/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 97 weight(decay=0.0), 104 weight(decay=0.0005), 103 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/yolov8_neutrophils_fold_1
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1         0G      1.808      5.921     0.9832        120        640:  20%|██        | 1/5 [00:57<03:51, 57.87s/it]
